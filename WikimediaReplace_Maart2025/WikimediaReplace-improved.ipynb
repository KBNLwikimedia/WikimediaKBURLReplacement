# %%
import mwclient
import re
import requests
import os
import logging
from typing import List, Set, Optional
from dotenv import load_dotenv
from tqdm import tqdm  # Import tqdm for progress bar

"""
This script automates the process of updating Wikimedia Commons files using the Wikimedia Commons API.
It searches for files matching a specific query, checks if they contain a target pattern,
and replaces it with a new pattern if found. The updated files are then saved back to Commons.

Features:
- Searches for files matching the given criteria.
- Logs into Wikimedia Commons using a bot account.
- Checks and updates file descriptions where needed.
- Saves changes with an appropriate edit summary.
- Displays a progress bar while processing files.

Requirements:
- Install `mwclient`, `requests`, `python-dotenv`, and `tqdm` via pip if not already installed.
- Ensure you have a Wikimedia bot account with appropriate permissions.
- Store credentials securely in a `.env` file.

Created by Olaf Janssen, Wikimedia coordinator of KB, national library of the Netherlands 
with much help from ChatGPT. 

Latest update: 8 March 2025

License = CC0, public domain.

"""

# Configure logging
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)

# Load environment variables from a .env file
load_dotenv()

# Wikimedia Commons login credentials (read from environment variables)
USERNAME = os.getenv("WIKIMEDIA_USERNAME", "").strip()
PASSWORD = os.getenv("WIKIMEDIA_PASSWORD", "").strip()
USER_AGENT = os.getenv("WIKIMEDIA_USER_AGENT", "").strip()

if not USERNAME or not PASSWORD:
    logging.error("Wikimedia credentials are missing. Please set WIKIMEDIA_USERNAME and WIKIMEDIA_PASSWORD in a .env file or as environment variables.")
    raise SystemExit(1)

if not USER_AGENT:
    logging.warning("User-Agent is not set. Some APIs may reject requests without it.")

# Wikimedia API URL and search parameters
SEARCH_URL = "https://commons.wikimedia.org/w/api.php"
SEARCH_PARAMS = {
    "action": "query",
    "format": "json",
    "list": "search",
    "srsearch": "insource:\"Category:Media from Delpher\"",
    "srlimit": 500,  # Adjust limit as needed, max=500 per query
    "srnamespace": 6,  # Namespace 6 = Files
    "sroffset" : 0
}

# Define text patterns to search and replace
#OLD_PATTERN = re.compile(r"\}\}\n== \{\{int:license-header\}\} ==\n\{\{PD-old-70-expired\}\}", re.MULTILINE)
#NEW_PATTERN = r"}}\n{{Delpher}}\n== {{int:license-header}} ==\n{{PD-old-70-expired}}"

OLD_PATTERN = re.compile(r"\[\[Category:Media from Delpher\]\]", re.MULTILINE)
NEW_PATTERN = r""

#OLD_PATTERN = re.compile(r"\}\}\n\n\[\[Category:De katholieke encyclopaedie\]\]", re.MULTILINE)
#NEW_PATTERN = r"}}\n{{Delpher}}\n[[Category:De katholieke encyclopaedie]]"


#OLD_PATTERN = re.compile(r"\}\}\n\[\[Category:", re.MULTILINE)
#NEW_PATTERN = r"}}\n{{Delpher}}\n[[Category:"

# Number of files to process per run
MAX_FILES = 60000
edit_summary="Removed [[Category:Media from Delpher]]"

def get_files() -> List[str]:
    """
    Retrieve up to MAX_FILES unique file titles from Wikimedia Commons based on a search query.
    Ensures that only MAX_FILES files are collected even if srlimit is higher.

    Returns:
        List[str]: A list of unique file titles.
    """
    all_files: Set[str] = set()
    params = SEARCH_PARAMS.copy()
    session = requests.Session()
    try:
        while len(all_files) < MAX_FILES:
            params["srlimit"] = min(SEARCH_PARAMS["srlimit"], MAX_FILES - len(all_files))  # Adjust limit dynamically
            response = session.get(SEARCH_URL, params=params, headers={"User-Agent": USER_AGENT})
            response.raise_for_status()
            data = response.json()

            # Extract file titles and ensure uniqueness
            files = {page["title"] for page in data.get("query", {}).get("search", [])}
            all_files.update(files)

            logging.info(f"Retrieved {len(all_files)} unique files so far...")

            # Stop if the required number of files is reached or if no more results are available
            if len(all_files) >= MAX_FILES or "continue" not in data:
                break

            # Update the continue parameter for the next request
            params.update(data["continue"])

    except requests.RequestException as e:
        logging.error(f"Error fetching file list: {e}")
        return []

    logging.info(f"Final count: {len(all_files)} unique files retrieved.")
    return list(all_files)


def login_to_commons() -> Optional[mwclient.Site]:
    """
    Log in to Wikimedia Commons using mwclient.

    Returns:
        mwclient.Site: Authenticated Wikimedia Commons site instance or None if login fails.
    """
    try:
        site = mwclient.Site("commons.wikimedia.org", clients_useragent=USER_AGENT)
        site.login(USERNAME, PASSWORD)
        logging.info("Successfully logged in to Wikimedia Commons.")
        return site
    except mwclient.LoginError as e:
        logging.error(f"Login failed: {e}")
    except Exception as e:
        logging.error(f"Unexpected error during login: {e}")
    
    return None

def has_multiple_delpher(text: str, limit: int) -> bool:
    """
    Checks if the text contains the {{Delpher}} template more than 'limit' times.

    Args:
        text (str): The text to check.

    Returns:
        bool: True if {{Delpher}} appears more than 'limit' times. False otherwise.
    """
    return text.count("{{Delpher}}") > int(limit)

def process_files(site: mwclient.Site, file_titles: List[str], edit_summary: str) -> None:
    """
    Check each file's wikitext and replace the target pattern if found, 
    ensuring that {{Delpher}} is not already present. A progress bar is displayed.
    
    Args:
        site (mwclient.Site): Authenticated Wikimedia Commons site instance.
        file_titles (List[str]): List of file titles to process.
    """
    if not file_titles:
        logging.warning("No files to process.")
        return

    for count, title in enumerate(tqdm(file_titles, desc="Processing files", unit="file"), start=1):
        try:
            page = site.pages[title]
            text = page.text()

            # Skip if {{Delpher}} is already present before the license header
            if has_multiple_delpher(text, 2): # text contains {{Delpher}} once or more
                logging.info(f"Skipping {title} - Template {{{{Delpher}}}} already present once or more times.")
                continue

            # Replace only if the exact OLD_PATTERN is found
            if OLD_PATTERN.search(text):
                new_text = OLD_PATTERN.sub(NEW_PATTERN, text)
                page.save(new_text, summary=edit_summary)
                logging.info(f"{count} - Updated: {title}")
            else:
                logging.info(f"Pattern not found, skipping: {title}")
        except mwclient.errors.APIError as e:
            logging.error(f"API error processing {title}: {e}")
        except Exception as e:
            logging.error(f"Error processing {title}: {e}")

def main() -> None:
    """
    Main function to orchestrate file retrieval, login, and processing.
    """
    file_titles = get_files()
    if not file_titles:
        logging.error("No files found or error retrieving files.")
        return

    site = login_to_commons()
    if not site:
        logging.error("Login failed, exiting script.")
        return

    process_files(site, file_titles, edit_summary)
    logging.info(f"Finished processing {len(file_titles)} files.")

if __name__ == "__main__":
    main()
# Out:
# 2025-03-12 23:55:37,376 - INFO - Retrieved 336 unique files so far...
# 2025-03-12 23:55:37,378 - INFO - Final count: 336 unique files retrieved.
# 2025-03-12 23:55:38,589 - INFO - Successfully logged in to Wikimedia Commons.
# 2025-03-12 23:55:38,891 - INFO - Pattern not found, skipping: File:De Tĳd - godsdienstig-staatkundig dagblad
# 2025-03-12 23:55:55,228 - INFO - 24 - Updated: File:Nieuwe Rotterdamsche courant - staats-, handels-, nieuws- en advertentieblad 24-11-1845 (IA ddd 010255929 mpeg21).pdf
# 2025-03-12 23:55:56,461 - INFO - 25 - Updated: File:Bredasche courant 09-06-1839 (IA ddd 010243997 mpeg21).pdf
# 2025-03-12 23:55:57,417 - INFO - 26 - Updated: File:De Tĳd - godsdienstig-staatkundig dagblad 15-06-1857 (IA ddd 010251775 mpeg21).pdf
# 2025-03-12 23:55:57,724 - INFO - Pattern not found, skipping: File:Arnhemsche courant 20-08-1846 (IA ddd 010209628 mpeg21).pdf
# 2025-03-12 23:55:58,090 - INFO - Pattern not found, skipping: File:Leeuwarder courant 01-10-1803 (IA ddd 010578438 mpeg21).pdf
# 2025-03-12 23:55:59,092 - INFO - 29 - Updated: File:De Tĳd - godsdienstig-staatkundig dagblad 12-10-1858 (IA ddd 010253224 mpeg21).pdf
# 2025-03-12 23:56:00,042 - INFO - 30 - Updated: File:Arnhemsche courant 03-02-1839 (IA ddd 010150566 mpeg21).pdf
# 2025-03-12 23:56:00,389 - INFO - Pattern not found, skipping: File:De Tĳd - godsdienstig-staatkundig dagblad 18-03-1858 (IA ddd 010253054 mpeg21).pdf
# 2025-03-12 23:56:00,703 - INFO - Pattern not found, skipping: File:Ommelander courant 13-01-1807 (IA ddd 010216038 mpeg21).pdf
# 2025-03-12 23:56:02,200 - INFO - 33 - Updated: File:Leeuwarder courant 05-09-1807 (IA ddd 010578846 mpeg21).pdf
# 2025-03-12 23:56:02,541 - INFO - Pattern not found, skipping: File:Arnhemsche courant 03-11-1846 (IA ddd 010209681 mpeg21).pdf
# 2025-03-12 23:56:02,842 - INFO - Pattern not found, skipping: File:Courrier d'Amsterdam = Courier van Amsterdam 24-01-1811 (IA ddd 010244875 mpeg21).pdf
# 2025-03-12 23:56:03,884 - INFO - 36 - Updated: File:Arnhemsche courant 05-11-1835 (IA ddd 010150211 mpeg21).pdf
# 2025-03-12 23:56:04,964 - INFO - 37 - Updated: File:De Tĳd - godsdienstig-staatkundig dagblad 18-01-1860 (IA ddd 010251955 mpeg21).pdf
# 2025-03-12 23:56:05,287 - INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 24-11-1831 (IA ddd 010520653 mpeg21).pdf
# 2025-03-12 23:56:05,657 - INFO - Pattern not found, skipping: File:Affiches, annonces et avis divers d'Amsterdam = Advertentiën, aankondigingen en verschillende berigten van Amsterdam 13-10-1813 (IA ddd 010202811 mpeg21).pdf
# 2025-03-12 23:56:06,643 - INFO - 40 - Updated: File:De Curaçaosche courant 23-09-1843 (IA ddd 010332100 mpeg21).pdf
# 2025-03-12 23:56:06,993 - INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 24-02-1816 (IA ddd 010515583 mpeg21).pdf
# 2025-03-12 23:56:07,978 - INFO - 42 - Updated: File:Noord-Brabander 13-09-1838 (IA ddd 010261986 mpeg21).pdf
# 2025-03-12 23:56:08,296 - INFO - Pattern not found, skipping: File:Noord-Brabander 22-05-1832 (IA ddd 010174655 mpeg21).pdf
# 2025-03-12 23:56:08,596 - INFO - Pattern not found, skipping: File:Arnhemsche courant 09-10-1841 (IA ddd 010150961 mpeg21).pdf
# 2025-03-12 23:56:09,564 - INFO - 45 - Updated: File:Bredasche courant 25-10-1855 (IA ddd 010153232 mpeg21).pdf
# 2025-03-12 23:56:10,573 - INFO - 46 - Updated: File:Arnhemsche courant 19-01-1837 (IA ddd 010148854 mpeg21).pdf
# 2025-03-12 23:56:10,976 - INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 04-03-1841 (IA ddd 010520080 mpeg21).pdf
# 2025-03-12 23:56:11,369 - INFO - Pattern not found, skipping: File:Courrier d'Amsterdam = Courier van Amsterdam 28-03-1811 (IA ddd 010244939 mpeg21).pdf
# 2025-03-12 23:56:11,683 - INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 09-01-1850 (IA ddd 010517590 mpeg21).pdf
# 2025-03-12 23:56:12,864 - INFO - 50 - Updated: File:Middelburgsche courant 30-12-1823 (IA ddd 010269008 mpeg21).pdf
# 2025-03-12 23:56:13,824 - INFO - 51 - Updated: File:De Curaçaosche courant 14-05-1836 (IA ddd 010334813 mpeg21).pdf
# 2025-03-12 23:56:14,121 - INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 24-07-1848 (IA ddd 010519740 mpeg21).pdf
# 2025-03-12 23:56:14,390 - INFO - Pattern not found, skipping: File:Bredasche courant 14-05-1843 (IA ddd 010151858 mpeg21).pdf
# 2025-03-12 23:56:14,678 - INFO - Pattern not found, skipping: File:Ommelander courant 24-08-1804 (IA ddd 010215758 mpeg21).pdf
# 2025-03-12 23:56:15,731 - INFO - 55 - Updated: File:Journal du département de la Frise = Dagblad van het departement Vriesland 15-11-1812 (IA ddd 010579634 mpeg21).pdf
# 2025-03-12 23:56:16,046 - INFO - Pattern not found, skipping: File:De avondbode - algemeen nieuwsblad voor staatkunde, handel, nijverheid, landbouw, kunsten, wetenschappen, enz. - door Ch.G. Withuys 22-02-1838 (IA ddd 010246082 mpeg21).pdf
# 2025-03-12 23:56:16,989 - INFO - 57 - Updated: File:Middelburgsche courant 29-05-1852 (IA ddd 010276329 mpeg21).pdf
# 2025-03-12 23:56:17,333 - INFO - Pattern not found, skipping: File:Journal de La Haye 27-03-1845 (IA ddd 010257626 mpeg21).pdf
# 2025-03-12 23:56:17,603 - INFO - Pattern not found, skipping: File:Bredasche courant 04-12-1853 (IA ddd 010153035 mpeg21).pdf
# 2025-03-12 23:56:18,678 - INFO - 60 - Updated: File:Bataafsche Leeuwarder courant 12-04-1804 (IA ddd 010172325 mpeg21).pdf
# 2025-03-12 23:56:18,948 - INFO - Pattern not found, skipping: File:Algemeen Nederlandsch nieuws- en advertentie-blad 26-08-1820 (IA ddd 010196268 mpeg21).pdf
# 2025-03-12 23:56:19,978 - INFO - 62 - Updated: File:Noord-Brabander 22-11-1836 (IA ddd 010175181 mpeg21).pdf
# 2025-03-12 23:56:20,949 - INFO - 63 - Updated: File:Bataafsche Leeuwarder courant 08-12-1804 (IA ddd 010172427 mpeg21).pdf
# 2025-03-12 23:56:21,252 - INFO - Pattern not found, skipping: File:Bataafsche Leeuwarder courant 13-09-1803 (IA ddd 010172234 mpeg21).pdf
# 2025-03-12 23:56:21,594 - INFO - Pattern not found, skipping: File:Koninklĳke courant 01-06-1809 (IA ddd 010239777 mpeg21).pdf
# 2025-03-12 23:56:21,880 - INFO - Pattern not found, skipping: File:Bredasche courant 21-06-1831 (IA ddd 010238683 mpeg21).pdf
# 2025-03-12 23:56:22,161 - INFO - Pattern not found, skipping: File:Bredasche courant 15-09-1830 (IA ddd 010238929 mpeg21).pdf
# 2025-03-12 23:56:22,457 - INFO - Pattern not found, skipping: File:Leeuwarder courant 08-05-1810 (IA ddd 010579124 mpeg21).pdf
# 2025-03-12 23:56:22,820 - INFO - Pattern not found, skipping: File:Bataafsche Leeuwarder courant
- INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 16-04-1816 (IA ddd 010515605 mpeg21).pdf
# 2025-03-12 23:59:13,527 - INFO - Pattern not found, skipping: File:Bataafsche Leeuwarder courant 20-05-1800 (IA ddd 010171617 mpeg21).pdf
# 2025-03-12 23:59:14,453 - INFO - 316 - Updated: File:Groninger courant 13-01-1809 (IA ddd 010170616 mpeg21).pdf
# 2025-03-12 23:59:15,584 - INFO - 317 - Updated: File:Bataafsche Leeuwarder courant 19-01-1802 (IA ddd 010171889 mpeg21).pdf
# 2025-03-12 23:59:16,837 - INFO - 318 - Updated: File:Leeuwarder courant 06-09-1800 (IA ddd 010578118 mpeg21).pdf
# 2025-03-12 23:59:17,301 - INFO - Pattern not found, skipping: File:Leeuwarder courant 07-01-1814 (IA ddd 010579884 mpeg21).pdf
# 2025-03-12 23:59:17,616 - INFO - Pattern not found, skipping: File:Bredasche courant 08-03-1833 (IA ddd 010243611 mpeg21).pdf
# 2025-03-12 23:59:17,893 - INFO - Pattern not found, skipping: File:Leeuwarder courant 31-01-1816 (IA ddd 010580214 mpeg21).pdf
# 2025-03-12 23:59:18,181 - INFO - Pattern not found, skipping: File:Journal du département de la Frise = Dagblad van het departement Vriesland 07-12-1812 (IA ddd 010579656 mpeg21).pdf
# 2025-03-12 23:59:18,429 - INFO - Pattern not found, skipping: File:Limburger Koerier vol 089 no 298 p 11 HOE HELPEN WE DE HUISHOUDING.djvu
# 2025-03-12 23:59:18,775 - INFO - Pattern not found, skipping: File:Journal de La Haye 05-02-1844 (IA ddd 010257271 mpeg21).pdf
# 2025-03-12 23:59:19,796 - INFO - 325 - Updated: File:De constitutioneel - nieuwe 's-Gravenhaagsche courant 16-12-1855 (IA ddd 010245254 mpeg21).pdf
# 2025-03-12 23:59:21,090 - INFO - 326 - Updated: File:De Curaçaosche courant 09-10-1852 (IA ddd 010332346 mpeg21).pdf
# 2025-03-12 23:59:21,402 - INFO - Pattern not found, skipping: File:Javasche courant 22-03-1837 (IA ddd 010500912 mpeg21).pdf
# 2025-03-12 23:59:21,694 - INFO - Pattern not found, skipping: File:Opregte Haarlemsche Courant 25-09-1823 (IA ddd 010516608 mpeg21).pdf
# 2025-03-12 23:59:21,991 - INFO - Pattern not found, skipping: File:Bredasche courant 12-07-1833 (IA ddd 010243716 mpeg21).pdf
# 2025-03-12 23:59:23,123 - INFO - 330 - Updated: File:Leeuwarder courant 12-02-1828 (IA ddd 010581495 mpeg21).pdf
# 2025-03-12 23:59:23,431 - INFO - Pattern not found, skipping: File:Journal de La Haye 01-06-1842 (IA ddd 010256746 mpeg21).pdf
# 2025-03-12 23:59:23,739 - INFO - Pattern not found, skipping: File:Arnhemsche courant 22-02-1846 (IA ddd 010209492 mpeg21).pdf
# 2025-03-12 23:59:24,022 - INFO - Pattern not found, skipping: File:Ommelander courant 18-09-1801 (IA ddd 010215481 mpeg21).pdf
# 2025-03-12 23:59:24,289 - INFO - Pattern not found, skipping: File:Bredasche courant 16-01-1831 (IA ddd 010238571 mpeg21).pdf
# 2025-03-12 23:59:25,584 - INFO - Pattern not found, skipping: File:De Curaçaosche courant 21-04-1849 (IA ddd 010332178 mpeg21).pdf
# 2025-03-12 23:59:26,577 - INFO - 336 - Updated: File:Courrier d'Amsterdam = Courier van Amsterdam 01-07-1811 (IA ddd 010245034 mpeg21).pdf
# Processing files: 100%|██████████| 336/336 [03:47<00:00,  1.47file/s]
# 2025-03-12 23:59:26,582 - INFO - Finished processing 336 files.
